# %%
# Load Layer 3 data
layer_3_path = "../../weights/linearity/lsr/safety_layer26_Layer3_Layer{i}.pt"
layer_3_data = []
import torch
for i in [5, 8, 11, 14, 17, 20, 23]:
    layer_3_data.append(torch.load(layer_3_path.format(i=i)))
layer_3_data.append(torch.load("../../weights/linearity/lsr/safety_layer26_Layer3.pt"))

# Load Layer 8 data
layer_8_path = "../../weights/linearity/lsr/safety_layer26_Layer8_Layer{i}.pt"
layer_8_data = []
for i in [10, 13, 16, 19, 22, 25]:
    layer_8_data.append(torch.load(layer_8_path.format(i=i)))
layer_8_data.append(torch.load("../../weights/linearity/lsr/safety_layer26_Layer8.pt"))

# Load Layer 12 data
layer_12_path = "../../weights/linearity/lsr/safety_layer26_Layer12_Layer{i}.pt"
layer_12_data = []
for i in [14, 17, 20, 23]:
    layer_12_data.append(torch.load(layer_12_path.format(i=i)))
layer_12_data.append(torch.load("../../weights/linearity/lsr/safety_layer26_Layer12.pt"))

# Load Layer 20 data
layer_20_path = "../../weights/linearity/lsr/safety_layer26_Layer20_Layer{i}.pt"
layer_20_data = []
for i in [22, 23, 24, 25]:
    layer_20_data.append(torch.load(layer_20_path.format(i=i)))
layer_20_data.append(torch.load("../../weights/linearity/lsr/safety_layer26_Layer20.pt"))

import matplotlib.pyplot as plt
import numpy as np
import warnings

# Suppress font warnings
warnings.filterwarnings('ignore', category=UserWarning, module='matplotlib')

# Set publication-quality style
plt.rcParams.update({
    'font.family': 'sans-serif',
    'font.sans-serif': ['DejaVu Sans', 'Arial', 'Helvetica'],
    'font.size': 12,
    'axes.labelsize': 14,
    'axes.titlesize': 16,
    'xtick.labelsize': 11,
    'ytick.labelsize': 11,
    'legend.fontsize': 11,
    'figure.titlesize': 18,
    'text.usetex': False,
    'axes.linewidth': 1.2,
    'grid.linewidth': 0.8,
    'lines.linewidth': 2,
})

# Create figure with four subplots
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(28, 5))

# Prepare data for box plots
data_to_plot_3 = [data.cpu().numpy() if torch.is_tensor(data) else data for data in layer_3_data]
data_to_plot_8 = [data.cpu().numpy() if torch.is_tensor(data) else data for data in layer_8_data]
data_to_plot_12 = [data.cpu().numpy() if torch.is_tensor(data) else data for data in layer_12_data]
data_to_plot_20 = [data.cpu().numpy() if torch.is_tensor(data) else data for data in layer_20_data]

# Define color palette (professional blue gradient)
box_color = '#2E86AB'
median_color = '#A23B72'
whisker_color = '#555555'

# Create box plot for Layer 3
bp1 = ax1.boxplot(data_to_plot_3, 
                   tick_labels=['L5', 'L8', 'L11', 'L14', 'L17', 'L20', 'L23', 'Logits'],
                   patch_artist=True,
                   widths=0.6,
                   medianprops=dict(color=median_color, linewidth=2.5),
                   boxprops=dict(facecolor=box_color, alpha=0.7, linewidth=1.2),
                   whiskerprops=dict(color=whisker_color, linewidth=1.2),
                   capprops=dict(color=whisker_color, linewidth=1.2),
                   flierprops=dict(marker='o', markerfacecolor='gray', markersize=4, alpha=0.5))

ax1.set_xlabel('Target Layer', fontweight='bold')
ax1.set_ylabel('Linearity Score (LSR)', fontweight='bold')
ax1.set_title('Steering Layer 3', fontweight='bold', pad=15)
ax1.grid(True, alpha=0.25, linestyle='--', linewidth=0.8)
# ax1.set_ylim(0.999, 1.01)
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)

# Create box plot for Layer 8
bp2 = ax2.boxplot(data_to_plot_8, 
                   tick_labels=['L10', 'L13', 'L16', 'L19', 'L22', 'L25', 'Logits'],
                   patch_artist=True,
                   widths=0.6,
                   medianprops=dict(color=median_color, linewidth=2.5),
                   boxprops=dict(facecolor=box_color, alpha=0.7, linewidth=1.2),
                   whiskerprops=dict(color=whisker_color, linewidth=1.2),
                   capprops=dict(color=whisker_color, linewidth=1.2),
                   flierprops=dict(marker='o', markerfacecolor='gray', markersize=4, alpha=0.5))

ax2.set_xlabel('Target Layer', fontweight='bold')
ax2.set_ylabel('Linearity Score (LSR)', fontweight='bold')
ax2.set_title('Steering Layer 8', fontweight='bold', pad=15)
ax2.grid(True, alpha=0.25, linestyle='--', linewidth=0.8)
ax2.set_ylim(0.999, 1.01)
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)

# Create box plot for Layer 12
bp3 = ax3.boxplot(data_to_plot_12, 
                   tick_labels=['L14', 'L17', 'L20', 'L23', 'Logits'],
                   patch_artist=True,
                   widths=0.6,
                   medianprops=dict(color=median_color, linewidth=2.5),
                   boxprops=dict(facecolor=box_color, alpha=0.7, linewidth=1.2),
                   whiskerprops=dict(color=whisker_color, linewidth=1.2),
                   capprops=dict(color=whisker_color, linewidth=1.2),
                   flierprops=dict(marker='o', markerfacecolor='gray', markersize=4, alpha=0.5))

ax3.set_xlabel('Target Layer', fontweight='bold')
ax3.set_ylabel('Linearity Score (LSR)', fontweight='bold')
ax3.set_title('Steering Layer 12', fontweight='bold', pad=15)
ax3.grid(True, alpha=0.25, linestyle='--', linewidth=0.8)
ax3.set_ylim(1, 1.0020)
ax3.spines['top'].set_visible(False)
ax3.spines['right'].set_visible(False)

# Create box plot for Layer 20
bp4 = ax4.boxplot(data_to_plot_20, 
                   tick_labels=['L22', 'L23', 'L24', 'L25', 'Logits'],
                   patch_artist=True,
                   widths=0.6,
                   medianprops=dict(color=median_color, linewidth=2.5),
                   boxprops=dict(facecolor=box_color, alpha=0.7, linewidth=1.2),
                   whiskerprops=dict(color=whisker_color, linewidth=1.2),
                   capprops=dict(color=whisker_color, linewidth=1.2),
                   flierprops=dict(marker='o', markerfacecolor='gray', markersize=4, alpha=0.5))

ax4.set_xlabel('Target Layer', fontweight='bold')
ax4.set_ylabel('Linearity Score (LSR)', fontweight='bold')
ax4.set_title('Steering Layer 20', fontweight='bold', pad=15)
ax4.grid(True, alpha=0.25, linestyle='--', linewidth=0.8)
ax4.set_ylim(1, 1.0020)
ax4.spines['top'].set_visible(False)
ax4.spines['right'].set_visible(False)

# Add subtle background
for ax in [ax1, ax2, ax3, ax4]:
    ax.set_facecolor('#F8F9FA')

plt.tight_layout()
plt.savefig('linearity_analysis.pdf', dpi=300, bbox_inches='tight', format='pdf')
plt.savefig('linearity_analysis.png', dpi=300, bbox_inches='tight', format='png')
plt.show()
