# %%
random_lsr_list = [
    3.1401875019073486,
    3.0446197986602783,
    2.842414379119873,
    2.849750518798828,
    2.8455939292907715,
]
safety_lsr_list = [
    2.9250054359436035,
    3.1249918937683105,
    3.2655205726623535,
    3.1612956523895264,
    2.9501430988311768,
]


import matplotlib.pyplot as plt

# Create the plot
plt.figure(figsize=(10, 6))
layers = list(range(5))  # x-axis: layers 0-4

plt.plot(layers, random_lsr_list, marker='o', label='Random LSR', linewidth=2)
plt.plot(layers, safety_lsr_list, marker='s', label='Safety LSR', linewidth=2)

plt.xlabel('Layer', fontsize=12)
plt.ylabel('LSR Value', fontsize=12)
plt.title('LSR Comparison: Random vs Safety', fontsize=14)
plt.legend(fontsize=10)
plt.grid(True, alpha=0.3)
plt.xticks(layers)
plt.tight_layout()
plt.ylim(2.8, 3.3)
plt.savefig('lsr_comparison.png')
plt.show()

# %%
mean_norm_list = [
    0.016854653134942055,
    0.019087398424744606,
    0.007580059114843607,
    0.010572360828518867,
    0.009546701796352863,
    0.01192552875727415,
]
mean_norm_list_big = [
    0.2842504680156708,
    0.3546462655067444,
    0.3710017800331116,
    0.3273596465587616,
    0.28940457105636597,
    0.17889118194580078,
]


import matplotlib.pyplot as plt

# Create the plot
plt.figure(figsize=(10, 6))
layers = list(range(6))  # x-axis: layers 0-5

plt.plot(layers, mean_norm_list, marker='o', label='Safety Norm', linewidth=2)
plt.plot(layers, mean_norm_list_big, marker='s', label='Random Norm', linewidth=2)

plt.xlabel('Layer', fontsize=12)
plt.ylabel('Mean Norm Value', fontsize=12)
plt.title('Norm Comparison: Safety vs Random', fontsize=14)
plt.legend(fontsize=10)
plt.grid(True, alpha=0.3)
plt.xticks(layers)
plt.tight_layout()
plt.savefig('norm_comparison.png')
plt.show()
